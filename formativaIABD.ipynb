# %%
import numpy as np  # importa biblioteca numpy para trabalhar com valores numéricos
from sklearn.model_selection import train_test_split # importa a biblioteca sklearn e o método para treinamento
from sklearn.tree import DecisionTreeClassifier # Da sklearn importa a árvore de decisão
from sklearn import tree
from sklearn.metrics import accuracy_score # metricas
from sklearn.metrics import precision_score # metricas
from sklearn.metrics import recall_score # metricas
from sklearn.metrics import f1_score # metricas
from sklearn.metrics import confusion_matrix # importa 
import matplotlib.pyplot as plt # matplotlib
import seaborn as sns # seaborn
import pandas as pd # importação do pandas
from sklearn import datasets

# %%
df = pd.read_csv('dados_produtos.csv')

# %%
df.head()
# Out:
#   product_name  rating  rating_count  purchased
# 0    Televisão    3.04            29          1
# 1      Celular    3.46          3872          0
# 2    Cafeteira    3.25          1187          0
# 3    Televisão    3.77          4097          1
# 4    Videogame    5.00          4738          1

# %%
# Dados de treinamento
x = df[['rating','rating_count']]
y = df['purchased']

# %%
x_a = np.array(x)
y_a = np.array(y)
print(x_a)
print(y_a)
# Out:
# [[3.040e+00 2.900e+01]
#  [3.460e+00 3.872e+03]
#  [3.250e+00 1.187e+03]
#  [3.770e+00 4.097e+03]
#  [5.000e+00 4.738e+03]
#  [3.980e+00 1.413e+03]
#  [3.500e+00 1.907e+03]
#  [4.760e+00 3.857e+03]
#  [3.940e+00 2.800e+03]
#  [4.680e+00 2.600e+03]
#  [4.430e+00 2.748e+03]
#  [3.140e+00 4.599e+03]
#  [4.420e+00 7.900e+01]
#  [3.140e+00 1.428e+03]
#  [3.620e+00 4.399e+03]
#  [4.100e+00 4.977e+03]
#  [3.930e+00 3.745e+03]
#  [4.610e+00 4.801e+03]
#  [4.180e+00 1.425e+03]
#  [3.110e+00 4.620e+03]
#  [4.240e+00 1.744e+03]
#  [4.950e+00 1.879e+03]
#  [4.490e+00 2.300e+02]
#  [3.600e+00 4.841e+03]
#  [4.920e+00 3.679e+03]
#  [3.120e+00 3.649e+03]
#  [4.890e+00 2.773e+03]
#  [3.760e+00 4.965e+03]
#  [3.760e+00 4.780e+03]
#  [4.940e+00 3.070e+03]
#  [3.020e+00 2.544e+03]
#  [4.120e+00 1.946e+03]
#  [3.230e+00 1.992e+03]
#  [4.450e+00 4.236e+03]
#  [4.080e+00 4.613e+03]
#  [4.000e+00 2.450e+02]
#  [3.310e+00 5.560e+02]
#  [3.040e+00 4.403e+03]
#  [4.800e+00 3.376e+03]
#  [4.310e+00 1.786e+03]
#  [3.820e+00 2.357e+03]
#  [3.450e+00 3.299e+03]
#  [3.050e+00 3.162e+03]
#  [3.690e+00 2.385e+03]
#  [3.450e+00 2.895e+03]
#  [4.980e+00 4.566e+03]
#  [4.960e+00 9.500e+02]
#  [3.750e+00 2.463e+03]
#  [5.000e+00 2.986e+03]
#  [3.390e+00 1.489e+03]
#  [3.330e+00 1.936e+03]
#  [4.950e+00 4.969e+03]
#  [4.800e+00 3.537e+03]
#  [4.240e+00 3.065e+03]
#  [4.970e+00 3.940e+02]
#  [4.230e+00 1.556e+03]
#  [4.680e+00 4.333e+03]
#  [3.510e+00 1.000e+01]
#  [3.160e+00 4.301e+03]
#  [4.990e+00 1.779e+03]
#  [4.240e+00 1.435e+03]
#  [3.490e+00 2.290e+02]
#  [4.110e+00 1.075e+03]
#  [4.680e+00 1.577e+03]
#  [4.390e+00 1.408e+03]
#  [3.710e+00 3.800e+02]
#  [4.550e+00 4.339e+03]
#  [3.520e+00 4.070e+02]
#  [4.470e+00 1.989e+03]
#  [4.230e+00 3.244e+03]
#  [4.010e+00 3.651e+03]
#  [4.670e+00 3.901e+03]
#  [3.790e+00 2.319e+03]
#  [3.040e+00 4.133e+03]
#  [3.440e+00 1.600e+01]
#  [3.780e+00 3.113e+03]
#  [3.870e+00 1.887e+03]
#  [3.690e+00 4.418e+03]
#  [4.600e+00 4.323e+03]
#  [4.420e+00 2.463e+03]
#  [3.380e+00 5.830e+02]
#  [4.330e+00 2.910e+03]
#  [3.810e+00 4.457e+03]
#  [4.360e+00 7.980e+02]
#  [4.290e+00 1.358e+03]
#  [4.140e+00 2.308e+03]
#  [4.120e+00 2.580e+02]
#  [3.700e+00 1.913e+03]
#  [4.810e+00 2.190e+03]
#  [3.840e+00 3.698e+03]
#  [3.990e+00 1.707e+03]
#  [4.640e+00 2.754e+03]
#  [4.350e+00 1.558e+03]
#  [4.150e+00 1.311e+03]
#  [4.780e+00 1.713e+03]
#  [4.440e+00 1.372e+03]
#  [4.660e+00 1.690e+03]
#  [4.330e+00 3.364e+03]
#  [3.300e+00 1.825e+03]
#  [4.080e+00 5.330e+02]]
# ['comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'comprou' 'comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'nao comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'comprou' 'nao comprou' 'comprou' 'nao comprou'
#  'comprou' 'nao comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'comprou' 'comprou' 'comprou' 'nao comprou' 'comprou'
#  'comprou' 'nao comprou' 'nao comprou' 'comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'nao comprou' 'nao comprou' 'nao comprou'
#  'comprou' 'nao comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou'
#  'nao comprou' 'comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'nao comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou'
#  'nao comprou' 'comprou' 'comprou' 'comprou' 'nao comprou']

# %%
# Substituir a coluna purchased pelas variáveis
df['purchased'] = df['purchased'].map({0:'nao comprou',1:'comprou'})

# %%
df.head()
# Out:
#   product_name  rating  rating_count    purchased
# 0    Televisão    3.04            29      comprou
# 1      Celular    3.46          3872  nao comprou
# 2    Cafeteira    3.25          1187  nao comprou
# 3    Televisão    3.77          4097      comprou
# 4    Videogame    5.00          4738      comprou

# %%
y_a = np.array(y)
print(y_a)
# Out:
# ['comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'comprou' 'comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'nao comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'comprou' 'nao comprou' 'comprou' 'nao comprou'
#  'comprou' 'nao comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'comprou' 'comprou' 'comprou' 'nao comprou' 'comprou'
#  'comprou' 'nao comprou' 'nao comprou' 'comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'nao comprou' 'nao comprou' 'nao comprou'
#  'comprou' 'nao comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou'
#  'nao comprou' 'comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'nao comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou'
#  'nao comprou' 'comprou' 'comprou' 'comprou' 'nao comprou']

# %%
# Dividir dados em treino e teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x_a, y_a, test_size=0.2, random_state=42)

# %%
# Cria o modelo de machine learn
modelo = DecisionTreeClassifier()

# %%
# Treinamento do modelo
modelo.fit(x_treino, y_treino)
# Out:
# DecisionTreeClassifier()

# %%
# Plotar figura da árvore de decisão
fig = plt.figure(figsize=(10,8))
tree.plot_tree(modelo, feature_names = x_a.tolist(), class_names =y_a.tolist(), filled= True)
# Out:
# [Text(0.5, 0.96875, '[3.46, 3872.0] <= 1962.5\ngini = 0.5\nsamples = 80\nvalue = [40, 40]\nclass = comprou'),
#  Text(0.3076923076923077, 0.90625, '[3.04, 29.0] <= 4.265\ngini = 0.422\nsamples = 33\nvalue = [23, 10]\nclass = comprou'),
#  Text(0.23076923076923078, 0.84375, '[3.04, 29.0] <= 3.61\ngini = 0.298\nsamples = 22\nvalue = [18, 4]\nclass = comprou'),
#  Text(0.19230769230769232, 0.78125, '[3.04, 29.0] <= 3.515\ngini = 0.463\nsamples = 11\nvalue = [7, 4]\nclass = comprou'),
#  Text(0.15384615384615385, 0.71875, '[3.46, 3872.0] <= 1458.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = comprou'),
#  Text(0.07692307692307693, 0.65625, '[3.04, 29.0] <= 3.465\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = comprou'),
#  Text(0.038461538461538464, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = comprou'),
#  Text(0.11538461538461539, 0.59375, '[3.46, 3872.0] <= 119.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.07692307692307693, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.15384615384615385, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = nao comprou'),
#  Text(0.23076923076923078, 0.65625, '[3.46, 3872.0] <= 1866.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = comprou'),
#  Text(0.19230769230769232, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = nao comprou'),
#  Text(0.2692307692307692, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.23076923076923078, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = nao comprou'),
#  Text(0.2692307692307692, 0.78125, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = comprou'),
#  Text(0.38461538461538464, 0.84375, '[3.46, 3872.0] <= 672.0\ngini = 0.496\nsamples = 11\nvalue = [5, 6]\nclass = nao comprou'),
#  Text(0.34615384615384615, 0.78125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.4230769230769231, 0.78125, '[3.04, 29.0] <= 4.955\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = nao comprou'),
#  Text(0.38461538461538464, 0.71875, '[3.46, 3872.0] <= 1365.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = comprou'),
#  Text(0.34615384615384615, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = nao comprou'),
#  Text(0.4230769230769231, 0.65625, '[3.46, 3872.0] <= 1633.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = comprou'),
#  Text(0.34615384615384615, 0.59375, '[3.46, 3872.0] <= 1483.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = comprou'),
#  Text(0.3076923076923077, 0.53125, '[3.46, 3872.0] <= 1390.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.2692307692307692, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.34615384615384615, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = nao comprou'),
#  Text(0.38461538461538464, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.5, 0.59375, '[3.04, 29.0] <= 4.865\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = nao comprou'),
#  Text(0.46153846153846156, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = nao comprou'),
#  Text(0.5384615384615384, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.46153846153846156, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = nao comprou'),
#  Text(0.6923076923076923, 0.90625, '[3.04, 29.0] <= 4.655\ngini = 0.462\nsamples = 47\nvalue = [17, 30]\nclass = nao comprou'),
#  Text(0.5769230769230769, 0.84375, '[3.46, 3872.0] <= 2424.0\ngini = 0.408\nsamples = 35\nvalue = [10, 25]\nclass = nao comprou'),
#  Text(0.5384615384615384, 0.78125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = nao comprou'),
#  Text(0.6153846153846154, 0.78125, '[3.46, 3872.0] <= 2608.5\ngini = 0.452\nsamples = 29\nvalue = [10, 19]\nclass = nao comprou'),
#  Text(0.5769230769230769, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.6538461538461539, 0.71875, '[3.04, 29.0] <= 4.28\ngini = 0.417\nsamples = 27\nvalue = [8, 19]\nclass = nao comprou'),
#  Text(0.6153846153846154, 0.65625, '[3.46, 3872.0] <= 3203.0\ngini = 0.472\nsamples = 21\nvalue = [8, 13]\nclass = nao comprou'),
#  Text(0.5769230769230769, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = nao comprou'),
#  Text(0.6538461538461539, 0.59375, '[3.04, 29.0] <= 3.115\ngini = 0.494\nsamples = 18\nvalue = [8, 10]\nclass = nao comprou'),
#  Text(0.6153846153846154, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.6923076923076923, 0.53125, '[3.04, 29.0] <= 4.165\ngini = 0.469\nsamples = 16\nvalue = [6, 10]\nclass = nao comprou'),
#  Text(0.6538461538461539, 0.46875, '[3.46, 3872.0] <= 3673.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = nao comprou'),
#  Text(0.6153846153846154, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = nao comprou'),
#  Text(0.6923076923076923, 0.40625, '[3.46, 3872.0] <= 3721.5\ngini = 0.473\nsamples = 13\nvalue = [5, 8]\nclass = nao comprou'),
#  Text(0.6538461538461539, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.7307692307692307, 0.34375, '[3.04, 29.0] <= 3.53\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = nao comprou'),
#  Text(0.6538461538461539, 0.28125, '[3.46, 3872.0] <= 4450.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = comprou'),
#  Text(0.6153846153846154, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.6923076923076923, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = nao comprou'),
#  Text(0.8076923076923077, 0.28125, '[3.46, 3872.0] <= 4535.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = nao comprou'),
#  Text(0.7692307692307693, 0.21875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = nao comprou'),
#  Text(0.8461538461538461, 0.21875, '[3.46, 3872.0] <= 4696.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = nao comprou'),
#  Text(0.8076923076923077, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.8846153846153846, 0.15625, '[3.46, 3872.0] <= 4903.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = nao comprou'),
#  Text(0.8461538461538461, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = nao comprou'),
#  Text(0.9230769230769231, 0.09375, '[3.46, 3872.0] <= 4971.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.8846153846153846, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.9615384615384616, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = nao comprou'),
#  Text(0.7307692307692307, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.6923076923076923, 0.65625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = nao comprou'),
#  Text(0.8076923076923077, 0.84375, '[3.46, 3872.0] <= 3768.0\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = comprou'),
#  Text(0.7692307692307693, 0.78125, '[3.46, 3872.0] <= 2686.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = nao comprou'),
#  Text(0.7307692307692307, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.8076923076923077, 0.71875, '[3.04, 29.0] <= 4.93\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = nao comprou'),
#  Text(0.7692307692307693, 0.65625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = nao comprou'),
#  Text(0.8461538461538461, 0.65625, '[3.46, 3872.0] <= 3028.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.8076923076923077, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = nao comprou'),
#  Text(0.8846153846153846, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.8461538461538461, 0.78125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = comprou')]

# %%
df.describe()
# Out:
#            rating  rating_count
# count  100.000000    100.000000
# mean     4.056900   2536.670000
# std      0.588344   1458.312544
# min      3.020000     10.000000
# 25%      3.580000   1433.250000
# 50%      4.105000   2424.000000
# 75%      4.505000   3773.000000
# max      5.000000   4977.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  100 non-null    object
#  1   rating        100 non-null    float64
#  2   rating_count  100 non-null    int64
#  3   purchased     100 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.3+ KB

# %%
df['product_name'] == 'Televisão'
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 95    False
# 96    False
# 97     True
# 98    False
# 99    False
# Name: product_name, Length: 100, dtype: bool

# %%
xtelevisao = df[['rating','rating_count']]
ytelevisao = df['purchased']

# %%
xtelevisao_a = np.array(x)
ytelevisao_a = np.array(y)
print(xtelevisao_a)
print(ytelevisao_a)
# Out:
# [[3.040e+00 2.900e+01]
#  [3.460e+00 3.872e+03]
#  [3.250e+00 1.187e+03]
#  [3.770e+00 4.097e+03]
#  [5.000e+00 4.738e+03]
#  [3.980e+00 1.413e+03]
#  [3.500e+00 1.907e+03]
#  [4.760e+00 3.857e+03]
#  [3.940e+00 2.800e+03]
#  [4.680e+00 2.600e+03]
#  [4.430e+00 2.748e+03]
#  [3.140e+00 4.599e+03]
#  [4.420e+00 7.900e+01]
#  [3.140e+00 1.428e+03]
#  [3.620e+00 4.399e+03]
#  [4.100e+00 4.977e+03]
#  [3.930e+00 3.745e+03]
#  [4.610e+00 4.801e+03]
#  [4.180e+00 1.425e+03]
#  [3.110e+00 4.620e+03]
#  [4.240e+00 1.744e+03]
#  [4.950e+00 1.879e+03]
#  [4.490e+00 2.300e+02]
#  [3.600e+00 4.841e+03]
#  [4.920e+00 3.679e+03]
#  [3.120e+00 3.649e+03]
#  [4.890e+00 2.773e+03]
#  [3.760e+00 4.965e+03]
#  [3.760e+00 4.780e+03]
#  [4.940e+00 3.070e+03]
#  [3.020e+00 2.544e+03]
#  [4.120e+00 1.946e+03]
#  [3.230e+00 1.992e+03]
#  [4.450e+00 4.236e+03]
#  [4.080e+00 4.613e+03]
#  [4.000e+00 2.450e+02]
#  [3.310e+00 5.560e+02]
#  [3.040e+00 4.403e+03]
#  [4.800e+00 3.376e+03]
#  [4.310e+00 1.786e+03]
#  [3.820e+00 2.357e+03]
#  [3.450e+00 3.299e+03]
#  [3.050e+00 3.162e+03]
#  [3.690e+00 2.385e+03]
#  [3.450e+00 2.895e+03]
#  [4.980e+00 4.566e+03]
#  [4.960e+00 9.500e+02]
#  [3.750e+00 2.463e+03]
#  [5.000e+00 2.986e+03]
#  [3.390e+00 1.489e+03]
#  [3.330e+00 1.936e+03]
#  [4.950e+00 4.969e+03]
#  [4.800e+00 3.537e+03]
#  [4.240e+00 3.065e+03]
#  [4.970e+00 3.940e+02]
#  [4.230e+00 1.556e+03]
#  [4.680e+00 4.333e+03]
#  [3.510e+00 1.000e+01]
#  [3.160e+00 4.301e+03]
#  [4.990e+00 1.779e+03]
#  [4.240e+00 1.435e+03]
#  [3.490e+00 2.290e+02]
#  [4.110e+00 1.075e+03]
#  [4.680e+00 1.577e+03]
#  [4.390e+00 1.408e+03]
#  [3.710e+00 3.800e+02]
#  [4.550e+00 4.339e+03]
#  [3.520e+00 4.070e+02]
#  [4.470e+00 1.989e+03]
#  [4.230e+00 3.244e+03]
#  [4.010e+00 3.651e+03]
#  [4.670e+00 3.901e+03]
#  [3.790e+00 2.319e+03]
#  [3.040e+00 4.133e+03]
#  [3.440e+00 1.600e+01]
#  [3.780e+00 3.113e+03]
#  [3.870e+00 1.887e+03]
#  [3.690e+00 4.418e+03]
#  [4.600e+00 4.323e+03]
#  [4.420e+00 2.463e+03]
#  [3.380e+00 5.830e+02]
#  [4.330e+00 2.910e+03]
#  [3.810e+00 4.457e+03]
#  [4.360e+00 7.980e+02]
#  [4.290e+00 1.358e+03]
#  [4.140e+00 2.308e+03]
#  [4.120e+00 2.580e+02]
#  [3.700e+00 1.913e+03]
#  [4.810e+00 2.190e+03]
#  [3.840e+00 3.698e+03]
#  [3.990e+00 1.707e+03]
#  [4.640e+00 2.754e+03]
#  [4.350e+00 1.558e+03]
#  [4.150e+00 1.311e+03]
#  [4.780e+00 1.713e+03]
#  [4.440e+00 1.372e+03]
#  [4.660e+00 1.690e+03]
#  [4.330e+00 3.364e+03]
#  [3.300e+00 1.825e+03]
#  [4.080e+00 5.330e+02]]
# ['comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'comprou' 'comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'nao comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'comprou' 'nao comprou' 'comprou' 'nao comprou'
#  'comprou' 'nao comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'comprou' 'comprou' 'comprou' 'nao comprou' 'comprou'
#  'comprou' 'nao comprou' 'nao comprou' 'comprou' 'nao comprou'
#  'nao comprou' 'nao comprou' 'nao comprou' 'nao comprou' 'nao comprou'
#  'comprou' 'nao comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou'
#  'nao comprou' 'comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'nao comprou' 'comprou' 'comprou' 'comprou' 'comprou'
#  'comprou' 'comprou' 'nao comprou' 'nao comprou' 'nao comprou'
#  'nao comprou' 'comprou' 'comprou' 'nao comprou' 'nao comprou' 'comprou'
#  'nao comprou' 'comprou' 'comprou' 'comprou' 'nao comprou']
